# %%
top_cities =['New York City','Los Angles','Chicago','Houston','Phoenix']
print(top_cities)
# Out:
# ['New York City', 'Los Angles', 'Chicago', 'Houston', 'Phoenix']

# %%
top_cities
# Out:
# ['New York City', 'Los Angles', 'Chicago', 'Houston', 'Phoenix']

# %%
top_cities[2]  #indices starts with 0
# Out:
# 'Chicago'

# %%
top_cities[0]
# Out:
# 'New York City'

# %%
top_cities[-1]
# Out:
# 'Phoenix'

# %%
top_cities[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 top_cities[5]
#
# IndexError: list index out of range

# %%
top_cities[0:2] # The first index is the first element to include in the slice,
# and the second index is the first element not to include in the slice
# Out:
# ['New York City', 'Los Angles']

# %%
top_cities[:]
# Out:
# ['New York City', 'Los Angles', 'Chicago', 'Houston', 'Phoenix']

# %%
top_cities[3:]
# Out:
# ['Houston', 'Phoenix']

# %%
top_cities[:3]
# Out:
# ['New York City', 'Los Angles', 'Chicago']

# %%
top_cities[1:0]
# Out:
# []

# %%
def show_truth():
    print(mysterious_var)
    
mysterious_var='Surprise!'
show_truth()
# Out:
# Surprise!

# %%
def show_truth():
    mysterious_var='New Surprise!' #local varibale
    print(mysterious_var)
    
mysterious_var='Surprise!' #global variable
print(mysterious_var)
show_truth()
print(mysterious_var)
# Out:
# Surprise!
# New Surprise!
# Surprise!

# %%
def show_truth():
    global mysterious_var
    mysterious_var='New Surprise!' 
    print(mysterious_var)
    
mysterious_var='Surprise!'
print(mysterious_var)
show_truth()
print(mysterious_var)
# Out:
# Surprise!
# New Surprise!
# New Surprise!

# %%
def show_truth():
    # mysterious_var=['New Surprise!','Surprise!'] 
    mysterious_var.append('New Surprise!')
    print(mysterious_var)
    
mysterious_var=['Surprise!']
print(mysterious_var)
show_truth()
print(mysterious_var)
# Out:
# ['Surprise!']
# ['Surprise!', 'New Surprise!']
# ['Surprise!', 'New Surprise!']

# %%
len('Hello !') # spaces count as well
# Out:
# 7

# %%
print('Hello, World!', end='.') # keyword using endline
print('Python speaking!')
# Out:
# Hello, World!.Python speaking!

# %%
# , default value for space character
fname ='John'
print('Your first name is',fname,'Welcome!',sep='-')
# Out:
# Your first name is-John-Welcome!

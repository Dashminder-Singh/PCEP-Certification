# %%
12_000_300 # underscores in numbers improve readability
# Out:
# 12000300

# %%
# scientific notation
# 3e4 = 3E4 = 3* 10000 = 30000
# 3e-4 = 3E-4 = 3 * 1/10000 = 0.0003
print(0.000000000000000000000000000000000000000000003)
# Out:
# 3e-45

# %%
# octal numbers
# start with 0O or 0o
print(0o123)
# Out:
# 83

# %%
# hexadecimal numbers
# start with 0X or 0x
print(0x123)
# Out:
# 291

# %%
print(0b1111)
# Out:
# 15

# %%
book_rating = [7,9,5,6,8]
book_rating.append(10)
# book_rating
print(book_rating)
# Out:
# [7, 9, 5, 6, 8, 10]

# %%
book_rating = [7,9,5,6,8]
book_rating.insert(1,12)  #shift towrds right when insert a new element in the list
print(book_rating)
# Out:
# [7, 12, 9, 5, 6, 8]

# %%
# iteratiing lists
book_rating = [7,9,5,6,8]
for item in book_rating:
    print('cuurent books:',item)
# Out:
# cuurent books: 7
# cuurent books: 9
# cuurent books: 5
# cuurent books: 6
# cuurent books: 8

# %%
book_rating = [7,9,5,6,8]
size = len(book_rating)
for item in range(size):
    print('Current index',item,'cuurent books:',book_rating[item])
# Out:
# Current index 0 cuurent books: 7
# Current index 1 cuurent books: 9
# Current index 2 cuurent books: 5
# Current index 3 cuurent books: 6
# Current index 4 cuurent books: 8

# %%
spendings = [32.45, 18.65, 23.5,78.23, 5.23]
add =0

for i in range(len(spendings)):
    add += spendings[i]
print('Total sum amount:',add)
# Out:
# Total sum amount: 158.05999999999997

# %%
spendings = [32.45, 18.65, 23.5,78.23, 5.23]
count =0

for i in range(len(spendings)):
    count +=1

print('Number of items:',count)
# Out:
# Number of items: 5

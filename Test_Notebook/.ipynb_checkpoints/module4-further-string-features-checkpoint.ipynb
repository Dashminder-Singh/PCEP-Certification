# %%
fav_band = 'Green Day'
print(fav_band[6])
# Out:
# D

# %%
print(fav_band[:5])  # counts space as char
# Out:
# Green

# %%
fav_band[6] ='H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fav_band[6] ='H'
#
# TypeError: 'str' object does not support item assignment

# %%
text = 'please cacptialise me'
print(text.upper())
# Out:
# PLEASE CACPTIALISE ME

# %%
# is numeric, checks whether your string contains digits only

user = input('Please provide a number: ')
if user.isnumeric():
    print('Thank you, that\'s a correct number!')
else:
    print('Sorry,',user,'is not a number!')
# Out:
# Please provide a number:  45
# Thank you, that's a correct number!

# %%
str_1 ='AADAM'

str_2= str_1[::-1]
print(str_1)
print('Reverse:',str_2)
# Out:
# AADAM
# Reverse: MADAA

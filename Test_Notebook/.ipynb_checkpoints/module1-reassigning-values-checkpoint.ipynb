# %%
age =28
print(age)
# Out:
# 28

# %%
age = 28
new_age =age +5
print(new_age)
print(age)
# Out:
# 33
# 28

# %%
age = 28
age +=7
print(age)
# Out:
# 35

# %%
text = 'hokus' + 'pokus'   # string concatenation
print(text)
# Out:
# hokuspokus

# %%
print('hokus' * 5)
# Out:
# hokushokushokushokushokus

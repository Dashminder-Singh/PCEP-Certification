# %%
# SystemExit
import sys

uname = input('What is your name?')
if uname == '':
    print('Empty name? I cannot work with that. I am closing the programm. Bye!')
    sys.exit()

print('Hello',uname)
print('Let us get started...')
# Out:
# What is your name?
# Empty name? I cannot work with that. I am closing the programm. Bye!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\dashm\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3755: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
Programming_languages = ['Java', 'Python','C++']
print(Programming_languages[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 Programming_languages = ['Java', 'Python','C++']
# ----> 2 print(Programming_languages[10])
#
# IndexError: list index out of range

# %%
ages = {'Jim': 30, 'Pam':28, 'Kevin':33}
ages['Michael']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 ages = {'Jim': 30, 'Pam':28, 'Kevin':33}
# ----> 2 ages['Michael']
#
# KeyError: 'Michael'

# %%
age = input('What is your age? ')
print('In 10 years, you will be',age+10)
# Out:
# What is your age?  28
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 age = input('What is your age? ')
# ----> 2 print('In 10 years, you will be',age+10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = int(input('What is your age? '))
# Out:
# What is your age?  a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 age = int(input('What is your age? '))
#
# ValueError: invalid literal for int() with base 10: 'a'

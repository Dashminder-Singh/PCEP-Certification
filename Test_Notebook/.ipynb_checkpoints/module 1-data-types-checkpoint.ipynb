# %%
greeting = 'Hello, friend!'
print(type(greeting))
# Out:
# <class 'str'>

# %%
age = 35
print(type(age))
# Out:
# <class 'int'>

# %%
speed1 = 4.5
speed2 = 4.0
speed3 = 4.
speed4 = 4
print(type(speed4))
# Out:
# <class 'int'>

# %%
am_i_ugly = True
print(type(am_i_ugly))
print(am_i_ugly)
# Out:
# <class 'bool'>
# True

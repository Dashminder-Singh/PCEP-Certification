# %%
print(+2)
# Out:
# 2

# %%
print(-3)
# Out:
# -3

# %%
# Order of operators
# 1. **
# 2. * / // %
# 3. + -

# %%
2+3*8
# Out:
# 26

# %%
(2+8)*4
# Out:
# 40

# %%
print(0.1 + 0.1 + 0.1)
# Out:
# 0.30000000000000004

# %%
2**2**3 # The exponentation operator (**) uses right-sided binding 
# (ie. starts from the right)
# Out:
# 256

# %%
print('hello')
# Out:
# hello

# %%
length=len('hello')

# %%
no = input('What is the number?')
# Out:
# What is the number? 4

# %%
# main role of print is to cause an effect and that print doesn't return
# any meaningful value, but it still returns a value.

print_return = print('Hello')
print(print_return)
# Out:
# Hello
# None

# %%
# None is very special kind of value in python
# None is used to describe a null value or no value at all

x=None

if x:
    print('None is true')
elif x is False:
    print('None is false')
else:
    print('None is not true, or false, none is just None')
# Out:
# None is not true, or false, none is just None

# %%
x=None

if x is None:
    print('yes')
if x == None:
    print('it does')
# Out:
# yes
# it does

# %%
def greet():
    print('Hello')

x=greet()
print(x)
# Out:
# Hello
# None

# %%
top_cities =['New York City','Los Angles','Singapore','Chicago','Houston','Phoenix']
del top_cities[2]
print(top_cities)
# Out:
# ['New York City', 'Los Angles', 'Chicago', 'Houston', 'Phoenix']

# %%
top_cities[2]
# Out:
# 'Chicago'

# %%
top_cities =['New York City','Los Angles','Singapore','Chicago','Houston','Phoenix']
del top_cities[2:]
# del top_cities[2:4]
# deleting all element staring at index two until the end of the list
print(top_cities)
# Out:
# ['New York City', 'Los Angles']

# %%
top_cities =['New York City','Los Angles','Singapore','Chicago','Houston','Phoenix']
del top_cities[:]
print(top_cities)
# Out:
# []

# %%
top_cities =['New York City','Los Angles','Singapore','Chicago','Houston','Phoenix']
del top_cities
print(top_cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 top_cities =['New York City','Los Angles','Singapore','Chicago','Houston','Phoenix']
#       2 del top_cities
# ----> 3 print(top_cities)
#
# NameError: name 'top_cities' is not defined

# %%
# available logical operators
# < less than
# > greater than
# <= less than or equal
# >= greater than or equal
# == equals
# != not equals

# %%
pwd = input('Do you know the secret password?')
if pwd != '--secret':
    print('not correct')
else:
    print('correct password')
# Out:
# Do you know the secret password? secret
# not correct

# %%
if True:
    print('condition met')
# Out:
# condition met

# %%
if False:
    print('condition met')

# %%
if 2==2:
    print('true')
# Out:
# true

# %%
if 2!=1:
    print('true')
# Out:
# true

# %%
if 2==1:
    print('true')

# %%
height_cm = float(input(' Hright converter: enter your height in cm: '))
print('Your height in feet is:',height_cm/30.48)
# Out:
#  Hright converter: enter your height in cm:  189
# Your height in feet is: 6.200787401574803

# %%
year_born = int(input('what year were you born?'))
print('In 2100, you will be', 2100 - year_born, 'years old, provided you live this long!')
# Out:
# what year were you born? 1998
# In 2100, you will be 102 years old, provided you live this long!

# %%
temp_c = input('Enter the temperature today in Celsius degrees: ')
temp_f = float(temp_c) * 1.8 +32
temp_statement = str(temp_c) + ' degrees Celsius equals ' + str(temp_f) + ' degree Fahrenhet'
print(temp_statement)
# Out:
# Enter the temperature today in Celsius degrees:  25
# 25 degrees Celsius equals 77.0 degree Fahrenhet

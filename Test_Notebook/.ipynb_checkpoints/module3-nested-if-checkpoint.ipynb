# %%
ans_a = input('Do you like traveeling? y/n: ')
if ans_a =='y':
    ans_b = input('And do you like Asia? y/n: ')
    if ans_b == 'y':
        print('Excellent! You can win a ticket to Thailand!')
    else:
        print('Sorry to hear that!')
else:
    print('Sorry to hear that!')
# Out:
# Do you like traveeling? y/n:  y
# And do you like Asia? y/n:  n
# Sorry to hear that!
